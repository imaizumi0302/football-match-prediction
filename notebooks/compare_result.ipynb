# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import json

# %%
# 1. 列の内容（文字列）の最大表示幅を「省略しない」に設定
pd.set_option('display.max_colwidth', None)

# 2. 表示される最大行数を増やす 
pd.set_option('display.max_rows', 100) 

# 3. 表示される最大列数を増やす 
pd.set_option('display.max_columns', None)

# %%
import os

# Notebook用にスクリプトの場所を手動で設定
BASE_DIR = r"C:\Users\image\Portfolio\Soccer analysis\soccer_pipeline\notebooks"

# プロジェクトのルート（soccer_pipeline）
ROOT_DIR = os.path.abspath(os.path.join(BASE_DIR, ".."))

data_file = os.path.join(ROOT_DIR,"data","evaluation_results_log.csv")

# %%
df = pd.read_csv(data_file)

display(df)
# Out:
#                                                                                                                                                                                                                                                                     Composite_ID  \
# 0                                                                                                away_last_points,away_season_wins_ave_overall,away_team,home_last_points,home_season_wins_ave_overall,home_team|{"learning_rate": 0.05, "n_estimators": 1000, "num_leaves": 32}
# 1  away_last_gd,away_last_points,away_recent_10_goal_diff,away_season_wins_ave_overall,away_team,home_last_gd,home_last_points,home_recent_10_goal_diff,home_season_wins_ave_overall,home_team,points_difference|{"learning_rate": 0.05, "n_estimators": 1000, "num_leaves": 32}
#
#                                                                                                                                                                                                                                           Features  \
# 0                                                                                                               ['home_team', 'away_team', 'home_season_wins_ave_overall', 'away_season_wins_ave_overall', 'home_last_points', 'away_last_points']
# 1  ['home_team', 'away_team', 'home_season_wins_ave_overall', 'away_season_wins_ave_overall', 'home_last_points', 'away_last_points', 'home_last_gd', 'away_last_gd', 'home_recent_10_goal_diff', 'away_recent_10_goal_diff', 'points_difference']
#
#                                                        Params_JSON  \
# 0  {"n_estimators": 1000, "learning_rate": 0.05, "num_leaves": 32}
# 1  {"n_estimators": 1000, "learning_rate": 0.05, "num_leaves": 32}
#
#              Timestamp  n_estimators  learning_rate  num_leaves  accuracy  \
# 0  2025-11-23 15:25:49          1000           0.05          32  0.550000
# 1  2025-12-02 13:51:01          1000           0.05          32  0.617734
#
#    log_loss  f1_macro  f1_weighted      f1_A      f1_D      f1_H
# 0  0.981205  0.292587     0.441830  0.175000  0.000000  0.702761
# 1  0.925063  0.455674     0.599175  0.512821  0.121212  0.732988

# %%
def best_metric(data,metric):
    if metric == "log_loss": 
        data = data.sort_values(metric,ascending=True)
    else:
        data = data.sort_values(metric,ascending=False)
    # 'Params_JSON' 列の文字列をすべてPythonの辞書に変換し、新しい列に格納
    data['Params_Dict'] = data['Params_JSON'].apply(json.loads)
    best_data = data.iloc[0,:]

    best_features = best_data["Features"]
    best_params = best_data["Params_Dict"]
    best_metric = best_data[metric]
    
    print("best_features")
    print(best_features)
    print()
    print("best_parameter")
    print(best_params)
    print()
    print("best_metric({})".format(metric))
    print(best_metric)
    print()
    display(data.head(1).T)

# %%
best_metric(df,"log_loss") #確認したいmetricの種類を指定
# Out:
# best_features
# ['home_team', 'away_team', 'home_season_wins_ave_overall', 'away_season_wins_ave_overall', 'home_last_points', 'away_last_points', 'home_last_gd', 'away_last_gd', 'home_recent_10_goal_diff', 'away_recent_10_goal_diff', 'points_difference']
#
# best_parameter
# {'n_estimators': 1000, 'learning_rate': 0.05, 'num_leaves': 32}
#
# best_metric(log_loss)
# 0.9250631968442012
#                                                                                                                                                                                                                                                                                            1
# Composite_ID   away_last_gd,away_last_points,away_recent_10_goal_diff,away_season_wins_ave_overall,away_team,home_last_gd,home_last_points,home_recent_10_goal_diff,home_season_wins_ave_overall,home_team,points_difference|{"learning_rate": 0.05, "n_estimators": 1000, "num_leaves": 32}
# Features                                     ['home_team', 'away_team', 'home_season_wins_ave_overall', 'away_season_wins_ave_overall', 'home_last_points', 'away_last_points', 'home_last_gd', 'away_last_gd', 'home_recent_10_goal_diff', 'away_recent_10_goal_diff', 'points_difference']
# Params_JSON                                                                                                                                                                                                                  {"n_estimators": 1000, "learning_rate": 0.05, "num_leaves": 32}
# Timestamp                                                                                                                                                                                                                                                                2025-12-02 13:51:01
# n_estimators                                                                                                                                                                                                                                                                            1000
# learning_rate                                                                                                                                                                                                                                                                           0.05
# num_leaves                                                                                                                                                                                                                                                                                32
# accuracy                                                                                                                                                                                                                                                                            0.617734
# log_loss                                                                                                                                                                                                                                                                            0.925063
# f1_macro                                                                                                                                                                                                                                                                            0.455674
# f1_weighted                                                                                                                                                                                                                                                                         0.599175
# f1_A                                                                                                                                                                                                                                                                                0.512821
# f1_D                                                                                                                                                                                                                                                                                0.121212
# f1_H                                                                                                                                                                                                                                                                                0.732988
# Params_Dict                                                                                                                                                                                                                  {'n_estimators': 1000, 'learning_rate': 0.05, 'num_leaves': 32}
